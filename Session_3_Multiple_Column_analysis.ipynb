# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
path='Visadataset.csv'           
visa_df=pd.read_csv(path) 
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
cat=visa_df.select_dtypes(include='object').columns
num=visa_df.select_dtypes(exclude='object').columns

# %% [markdown]
# **Make a Frequency Table**

# %%
keys=visa_df['continent'].value_counts().keys()
values=visa_df['continent'].value_counts().values
df=pd.DataFrame(zip(keys,values),
               columns=['label','No of applicants'])
df.to_csv('continent.csv',index=False)

# %% [markdown]
# **Idea**
#
#
# - I want to create all frequency tables
#
# - and want to save in a new folder
#
# - The folder should avaliable in python current file location
#
# - All step automate

# %% [markdown]
# **step-1 Create a folder using python code**

# %%
# step-1 Create a folder using python code

# for creating folder use import os
 # os.makedirs will help you to save the folder in juypter file


import os 
os.makedirs('frequency_table')
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[6], line 8
#       1 # step-1 Create a folder using python code
#       2
#       3 # for creating folder use import os
#       4  # os.makedirs will help you to save the folder in juypter file
#       7 import os
# ----> 8 os.makedirs('frequency_table')
#
# File ~\anaconda3\Lib\os.py:228, in makedirs(name, mode, exist_ok)
#     226         return
#     227 try:
# --> 228     mkdir(name, mode)
#     229 except OSError:
#     230     # Cannot rely on checking for EEXIST, since the operating system
#     231     # could give priority to other errors like EACCES or EROFS
#     232     if not exist_ok or not path.isdir(name):
#
# FileExistsError: [WinError 183] Cannot create a file when that file already exists: 'frequency_table'

# %%
# now frequency_table name ka folder python file me create hua hoga
# if we run again the above code it will show file already existed error
# and to void this error use try and except,just like this

# %%
try:
    import os
    os.makedirs('frequency_table')
except Exception as e:
    print(e)
# Out:
# [WinError 183] Cannot create a file when that file already exists: 'frequency_table'

# %%
# Or do something like this 
os.makedirs('frequency_table',exist_ok=True)
# so here exist_ok=True means agar frequency table exist nahi hai to vo usse create karega 
# and agar vo already exist hai to usse double double create nahi hone dega

# %%
# now below code i want to save in frequency table folder how can i do it
# method-1
# keys=visa_df['continent'].value_counts().keys()
# values=visa_df['continent'].value_counts().values
# df=pd.DataFrame(zip(keys,values),
#                columns=['label','No of applicants'])
# df.to_csv('continent.csv',index=False)



# now do like this

keys=visa_df['continent'].value_counts().keys()
values=visa_df['continent'].value_counts().values
df=pd.DataFrame(zip(keys,values),
               columns=['label','No of applicants'])
path=r'C:\Users\LENOVO\Documents\Naresh IT\EDA\frequency_table\continent.csv'
df.to_csv(path,index=False)

# %%
# go to home and check the frequency table folder where continent.csv aa gaya

# %%
# absolute path
# path=r'C:\Users\LENOVO\Documents\Naresh IT\EDA\frequency_table\continent.csv'
# so this path is called absolute path 


# Relative path
# path=r.\frequency_table\continent1.csv
# this path is called relative path

# %%
# Method-2
path=r'.\frequency_table\continent1.csv'
df.to_csv(path,index=False)

# %%
# The entire path have 3 location

# 1. Python location  : cwd
# 2. folder name      : frequency table
# 3. filename         : continent.csv
# now I want to join all these above three

# %%
# so when use getcwd() to hume EDA folder tak ka access mil jata hai 
# that's why we are using getcwd() instead of 'C:\Users\LENOVO\Documents\Naresh IT\EDA'
cwd=os.getcwd()
cwd
# Out:
# 'C:\\Users\\LENOVO\\Documents\\Naresh IT\\EDA'

# %%
# method-3
cwd=os.getcwd()
folder_name='frequency_table'
new_dir=os.path.join(cwd,folder_name)
file_name='continent2.csv'
path=os.path.join(new_dir,file_name)
df.to_csv(path,index=False)

# %%
# folder_name='frequency_table'
# os.makedirs(folder_name,exist_ok=True)

# cwd = os.getcwd()

# file_name='continent2.csv'

# path=os.path.join(cwd,folde_name,file_name)

# df.to_csv(path,index=False)
# now delete all the folders till we created
# beacuse we want to automate now

# %%
cat   # so here there is 9 cateogrical column, in that don't consiser case_id
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'region_of_employment', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
cat[1:]  # so here case_id will be exclude
# Out:
# Index(['continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'region_of_employment', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
visa_df['case_id'].nunique()
# this is not useful
# Out:
# 25480

# %%
# All together

#step-1
keys=visa_df['continent'].value_counts().keys()
values=visa_df['continent'].value_counts().values
df=pd.DataFrame(zip(keys,values),
               columns=['label','No of applicants'])

# Step-2
folder_name='frequency_table'
os.makedire(foldername,exist_ok=True)


#Step-3
cwd=os.getcwd()
new_dir=os.path.join(cwd,folder_name)
file_name='continent.csv'
path=os.path.join(new_dir,file_name)


# Step-4:
df.to_csv(path,index=False)

# %%
# so in the above code what is common and what is changing
# so in the above code strings should be change
# use 'i' to get together all folder

# %%
# Step-1
for i in cat[1:]:
    #step-1
    keys=visa_df[i].value_counts().keys()
    values=visa_df[i].value_counts().values
    df=pd.DataFrame(zip(keys,values),
                   columns=['label','No of applicants'])
    
    # Step-2
    folder_name='frequency_table'
    os.makedirs(folder_name,exist_ok=True)
    
    
    #Step-3
    cwd=os.getcwd()
    new_dir=os.path.join(cwd,folder_name)
    file_name=f'{i}.csv'
    path=os.path.join(new_dir,file_name)
    
    
    # Step-4:
    df.to_csv(path,index=False)

# %%
# now bar chart and pie chart we have to like above

# %% [markdown]
# **Bar Chart Automate**

# %%
keys=visa_df[i].value_counts().keys()
values=visa_df[i].value_counts().values
plt.figure(figsize=(10,4))
plt.bar(keys,values)
plt.xlabel('labels')
plt.ylabel('count')
plt.title('Continent_barchart')
plt.savefig('Continent_bar.jpg')
plt.show()

# %%
# Step-1
for i in cat[1:]:    
    #step-1
    keys=visa_df[i].value_counts().keys()
    values=visa_df[i].value_counts().values
    plt.figure(figsize=(10,3))
    plt.bar(keys,values)

    
    # Step-2
    folder_name='Bar Charts'
    os.makedirs(folder_name,exist_ok=True)
    
    
    #Step-3
    cwd=os.getcwd()
    new_dir=os.path.join(cwd,folder_name)
    file_name=f'{i}.jpg'
    path=os.path.join(new_dir,file_name)
    
    
    # Step-4:
    plt.savefig(path)

# %% [markdown]
# **pie chart Automation**

# %%
# Step-1
for i in cat[1:]:    
    #step-1
    keys=visa_df[i].value_counts().keys()
    values=visa_df[i].value_counts().values
    plt.pie(values,
            labels=keys,
           explode=[0.1 for i in range(len(keys))])

    
    # Step-2
    folder_name='Pie Chart'
    os.makedirs(folder_name,exist_ok=True)
    
    
    #Step-3
    cwd=os.getcwd()
    new_dir=os.path.join(cwd,folder_name)
    file_name=f'{i}.jpg'
    path=os.path.join(new_dir,file_name)
    
    
    # Step-4:
    plt.savefig(path)
    plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


path='Visadataset.csv'           
visa_df=pd.read_csv(path) 



cat=visa_df.select_dtypes(include='object').columns
num=visa_df.select_dtypes(exclude='object').columns

# %% [markdown]
# **subplot**
#
# - multiplots we can plot in a single area

# %%
plt.subplot(2,2,1)  # here 2,2 means uss subplot ka area 2 by 2 ka hai, and 1 means it's a first plot
plt.subplot(2,2,2)
plt.subplot(2,2,3)
plt.subplot(2,2,4)
# Out:
# <Axes: >

# %%
plt.subplot(2,2,1)  
plt.title('2-2-1')
plt.subplot(2,2,2)
plt.title('2-2-2')
plt.subplot(2,2,3)
plt.title('2-2-3')
plt.subplot(2,2,4)
plt.title('2-2-4')
# Out:
# Text(0.5, 1.0, '2-2-4')

# %%
plt.subplot(1,3,1)  # here 1,3 means 1 row & 3 columns 
plt.subplot(1,3,2)
plt.subplot(1,3,3)
# Out:
# <Axes: >

# %%
plt.subplot(3,1,1)   # here 3,1 means 3 rows 1 columns 
plt.subplot(3,1,2) 
plt.subplot(3,1,3)
# Out:
# <Axes: >

# %%
# now i want to draw total 9 cat cols are there 
# in that we should not casider case_id
# so remaing8 columns, we need to do 8 columns
# (1,8) or (2,4) Or (4,2) or (3,3)

# %%
# plt.subplot(2,2,1)  
# plt.subplot(2,2,2)
# plt.subplot(2,2,3)
# plt.subplot(2,2,4)

# now here observe what is common and what is changing
# plt.subplot(2,2,i)
for i in range(1,5):
    plt.subplot(2,2,i)

# %%
# now i want 9 plots, how can i do that
for i in range(1,10):
    plt.subplot(3,3,i)

# %%
# keys=visa_df[i].value_counts().keys()
# values=visa_df[i].value_counts().values
# plt.figure(figsize=(10,4))
# plt.bar(keys,values)
# so this is our orignal code

# %%
# so iss code ko kuch iss tarah se likho ki har box me vo bar chart aane chaiye

# %%
for i in cat[1:]:
    keys=visa_df[i].value_counts().keys()
    values=visa_df[i].value_counts().values
    plt.figure(figsize=(10,4))
    plt.subplot(3,3,i)
    plt.bar(keys,values)

# now in this code there is problem 
# what is 'i'

for i in cat[1:]:
    keys=visa_df[i].value_counts().keys()   # i: column name
    values=visa_df[i].value_counts().values      # i: column name
    plt.figure(figsize=(10,4))
    plt.subplot(3,3,i)                  # i: number
    plt.bar(keys,values)

# %%
for i in range(1,len(cat)):              # cat[0] is case_id that we are using & we are taking cat[1]
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8

# %%
for i in range(1,len(cat)):
    print(i,cat[i])
# Out:
# 1 continent
# 2 education_of_employee
# 3 has_job_experience
# 4 requires_job_training
# 5 region_of_employment
# 6 unit_of_wage
# 7 full_time_position
# 8 case_status

# %%
# so here when I used 'i' then I am giving a numbers
# but when I am using cat[i] then I am using column loop
# in short consider karo ki hum 2 for loop use kar rahe hai
# for two different in one code

# %%
for i in range(1,len(cat)):     # this is wrong way
    keys=visa_df[cat[i]].value_counts().keys()  
    values=visa_df[cat[i]].value_counts().values
    plt.figure(figsize=(10,4))   # this figure size should not be in the code it should be at the top  
    plt.subplot(3,3,i)           # otherwise it will not (3,3,i) chart      
    plt.bar(keys,values)

# %%
plt.figure(figsize=(16,8))      # this is wrong way too
for i in range(1,len(cat)):
    keys=visa_df[cat[i]].value_counts().keys()  
    values=visa_df[cat[i]].value_counts().values
    plt.figure(figsize=(10,4))   # this figure size should not be in the code it should be at the top  
    plt.subplot(3,3,i)           # otherwise it will not (3,3,i) chart      
    plt.bar(keys,values)

# %%
plt.figure(figsize=(26,10))         # this is the correct way
for i in range(1,len(cat)):
    keys=visa_df[cat[i]].value_counts().keys()  
    values=visa_df[cat[i]].value_counts().values  
    plt.subplot(3,3,i)               
    plt.bar(keys,values)

# %%
# now give suptitle (super title)
plt.figure(figsize=(26,10))         
for i in range(1,len(cat)):
    keys=visa_df[cat[i]].value_counts().keys()  
    values=visa_df[cat[i]].value_counts().values  
    plt.subplot(3,3,i)
    plt.suptitle('BarCharts')
    plt.bar(keys,values)

# %%
plt.figure(figsize=(12,10))
for i in range(1,len(cat)):
    continent_keys=visa_df[cat[i]].value_counts().keys()
    continent_values=visa_df[cat[i]].value_counts().values
    plt.subplot(3,3,i)
    # plt.title(f'{cat[i]}_bar_charts')
    plt.pie(continent_values,
           labels=continent_keys,
            explode=[0.1 for i in range(len(continent_keys))])
    plt.title(f'{cat[i]}_bar_charts')
    # plt.show()
